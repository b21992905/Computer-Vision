# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/results/results_sample_data_2.csv")

# %%
df
# Out:
#       Unnamed: 0                 Patient_id  \
# 0              0  ID00358637202295388077032
# 1              1  ID00358637202295388077032
# 2              2  ID00358637202295388077032
# 3              3  ID00358637202295388077032
# 4              4  ID00358637202295388077032
# ...          ...                        ...
# 5290        5290  ID00169637202238024117706
# 5291        5291  ID00169637202238024117706
# 5292        5292  ID00169637202238024117706
# 5293        5293  ID00169637202238024117706
# 5294        5294  ID00169637202238024117706
#
#                                              Image_path  \
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# ...                                                 ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...
#
#                                               Mask_path  \
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# ...                                                 ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...
#
#                                         Image_mask_path  Class
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# ...                                                 ...    ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
#
# [5295 rows x 6 columns]

# %%
import tensorflow
from  tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

df.Class = df.Class.astype(str)
datagen = ImageDataGenerator()

target_size=(128,128)

train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Create separate data generators for training and validation
train_data_generator = ImageDataGenerator(
    # Your data augmentation and preprocessing parameters here
).flow_from_dataframe(
    dataframe=train_df,
    x_col="Image_path",
    y_col="Class",
    batch_size=64,
    seed=42,
    class_mode='sparse',
    shuffle=True,
    target_size=target_size,
)

val_data_generator = ImageDataGenerator().flow_from_dataframe(
    dataframe=val_df,
    x_col="Image_path",
    y_col="Class",
    batch_size=64,
    seed=42,
    class_mode='sparse',
    shuffle=False,  # No need to shuffle validation data
    target_size=target_size,
)
# Out:
# Found 4236 validated image filenames belonging to 5 classes.
# Found 1059 validated image filenames belonging to 5 classes.

# %%
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
base_model=InceptionResNetV2(weights='imagenet',include_top=False, input_shape=(128, 128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 1s 0us/step

# %%
from keras.models import Model

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(5, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.1, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
import tensorflow as tf
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

history = model.fit(train_data_generator,
                    steps_per_epoch=4236   //64,
                    epochs = 20,
                    validation_data=val_data_generator,
                    validation_steps= 1059 // 64,
                    callbacks = [callback])
# Out:
# Epoch 1/20
# 66/66 [==============================] - 2050s 30s/step - loss: 0.6483 - accuracy: 0.7454 - val_loss: 0.9112 - val_accuracy: 0.6270
# Epoch 2/20
# 66/66 [==============================] - 41s 613ms/step - loss: 0.2823 - accuracy: 0.8917 - val_loss: 0.7491 - val_accuracy: 0.7256
# Epoch 3/20
# 66/66 [==============================] - 41s 620ms/step - loss: 0.1916 - accuracy: 0.9199 - val_loss: 0.5506 - val_accuracy: 0.7998
# Epoch 4/20
# 66/66 [==============================] - 41s 618ms/step - loss: 0.1583 - accuracy: 0.9322 - val_loss: 0.3108 - val_accuracy: 0.8730
# Epoch 5/20
# 66/66 [==============================] - 44s 664ms/step - loss: 0.1413 - accuracy: 0.9384 - val_loss: 0.1948 - val_accuracy: 0.9268
# Epoch 6/20
# 66/66 [==============================] - 39s 594ms/step - loss: 0.1319 - accuracy: 0.9430 - val_loss: 0.1850 - val_accuracy: 0.9150
# Epoch 7/20
# 66/66 [==============================] - 41s 623ms/step - loss: 0.1145 - accuracy: 0.9477 - val_loss: 0.1653 - val_accuracy: 0.9385
# Epoch 8/20
# 66/66 [==============================] - 44s 663ms/step - loss: 0.1111 - accuracy: 0.9501 - val_loss: 0.1634 - val_accuracy: 0.9395
# Epoch 9/20
# 66/66 [==============================] - 43s 657ms/step - loss: 0.1115 - accuracy: 0.9477 - val_loss: 0.1612 - val_accuracy: 0.9355
# Epoch 10/20
# 66/66 [==============================] - 43s 655ms/step - loss: 0.1111 - accuracy: 0.9485 - val_loss: 0.1663 - val_accuracy: 0.9365
# Epoch 11/20
# 66/66 [==============================] - 43s 653ms/step - loss: 0.1117 - accuracy: 0.9470 - val_loss: 0.1643 - val_accuracy: 0.9414
# Epoch 12/20
# 66/66 [==============================] - 43s 653ms/step - loss: 0.1129 - accuracy: 0.9473 - val_loss: 0.1843 - val_accuracy: 0.9326
# Epoch 13/20
# 66/66 [==============================] - 43s 651ms/step - loss: 0.1099 - accuracy: 0.9475 - val_loss: 0.1685 - val_accuracy: 0.9404
# Epoch 14/20
# 66/66 [==============================] - 40s 600ms/step - loss: 0.1097 - accuracy: 0.9485 - val_loss: 0.1580 - val_accuracy: 0.9434
# Epoch 15/20
# 66/66 [==============================] - 41s 618ms/step - loss: 0.1078 - accuracy: 0.9497 - val_loss: 0.1573 - val_accuracy: 0.9453
# Epoch 16/20
# 66/66 [==============================] - 43s 652ms/step - loss: 0.1115 - accuracy: 0.9492 - val_loss: 0.1618 - val_accuracy: 0.9404
# Epoch 17/20
# 66/66 [==============================] - 43s 651ms/step - loss: 0.1073 - accuracy: 0.9497 - val_loss: 0.1684 - val_accuracy: 0.9375
# Epoch 18/20
# 66/66 [==============================] - 40s 608ms/step - loss: 0.1067 - accuracy: 0.9518 - val_loss: 0.1675 - val_accuracy: 0.9385
# Epoch 19/20
# 66/66 [==============================] - 40s 595ms/step - loss: 0.1149 - accuracy: 0.9477 - val_loss: 0.2068 - val_accuracy: 0.9268
# Epoch 20/20
# 66/66 [==============================] - 43s 656ms/step - loss: 0.1120 - accuracy: 0.9499 - val_loss: 0.1611 - val_accuracy: 0.9375

# %%
import numpy as np
y_pred = model.predict_generator(val_data_generator, 1059 // 64+1)
Y_pred = np.argmax(y_pred, axis=1)
# Out:
# <ipython-input-9-f6fcdf5d96bf>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(val_data_generator, 1059 // 64+1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics

confusion_matrix = confusion_matrix(val_data_generator.classes, Y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
print(classification_report(val_data_generator.classes, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       327
#            1       0.96      0.90      0.93       181
#            2       0.91      0.85      0.88        47
#            3       0.98      0.88      0.93       179
#            4       0.87      0.99      0.93       325
#
#     accuracy                           0.94      1059
#    macro avg       0.94      0.91      0.93      1059
# weighted avg       0.94      0.94      0.94      1059

# %%
from sklearn.metrics import accuracy_score
accuracy_score(val_data_generator.classes, Y_pred)
# Out:
# 0.9376770538243626
