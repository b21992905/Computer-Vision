# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/results/results.csv")

# %%
df
# Out:
#       Unnamed: 0                 Patient_id  \
# 0              0  ID00358637202295388077032
# 1              1  ID00358637202295388077032
# 2              2  ID00358637202295388077032
# 3              3  ID00358637202295388077032
# 4              4  ID00358637202295388077032
# ...          ...                        ...
# 5290        5290  ID00168637202237852027833
# 5291        5291  ID00168637202237852027833
# 5292        5292  ID00168637202237852027833
# 5293        5293  ID00168637202237852027833
# 5294        5294  ID00168637202237852027833
#
#                                              Image_path  \
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# ...                                                 ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...
#
#                                               Mask_path  \
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...
# ...                                                 ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...
#
#                                         Image_mask_path  Class
# 0     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 1     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 2     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 3     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# 4     /content/drive/MyDrive/Colab Notebooks/Pulmona...      1
# ...                                                 ...    ...
# 5290  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5291  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5292  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5293  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
# 5294  /content/drive/MyDrive/Colab Notebooks/Pulmona...      5
#
# [5295 rows x 6 columns]

# %%
import tensorflow
from  tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

df.Class = df.Class.astype(str)
datagen = ImageDataGenerator()

target_size=(128,128)

train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# Create separate data generators for training and validation
train_data_generator = ImageDataGenerator(
    # Your data augmentation and preprocessing parameters here
).flow_from_dataframe(
    dataframe=train_df,
    x_col="Mask_path",
    y_col="Class",
    batch_size=64,
    seed=42,
    class_mode='sparse',
    shuffle=True,
    target_size=target_size,
)

val_data_generator = ImageDataGenerator().flow_from_dataframe(
    dataframe=val_df,
    x_col="Mask_path",
    y_col="Class",
    batch_size=64,
    seed=42,
    class_mode='sparse',
    shuffle=False,  # No need to shuffle validation data
    target_size=target_size,
)
# Out:
# Found 4236 validated image filenames belonging to 5 classes.
# Found 1059 validated image filenames belonging to 5 classes.

# %%
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten
from keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input
import tensorflow as tf
base_model=InceptionResNetV2(weights='imagenet',include_top=False, input_shape=(128, 128, 3))

# %%
from keras.models import Model

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(5, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# %%
from keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.1, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
import tensorflow as tf
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

history = model.fit(train_data_generator,
                    steps_per_epoch=4236   //64,
                    epochs = 20,
                    validation_data=val_data_generator,
                    validation_steps= 1059 // 64,
                    callbacks = [callback])
# Out:
# Epoch 1/20
# 66/66 [==============================] - 1776s 26s/step - loss: 0.8949 - accuracy: 0.6330 - val_loss: 19.0540 - val_accuracy: 0.2676
# Epoch 2/20
# 66/66 [==============================] - 1514s 23s/step - loss: 0.5502 - accuracy: 0.7768 - val_loss: 3.3144 - val_accuracy: 0.3154
# Epoch 3/20
# 66/66 [==============================] - 1534s 23s/step - loss: 0.4543 - accuracy: 0.8116 - val_loss: 0.9443 - val_accuracy: 0.6953
# Epoch 4/20
# 66/66 [==============================] - 1536s 23s/step - loss: 0.4187 - accuracy: 0.8284 - val_loss: 0.6283 - val_accuracy: 0.7754
# Epoch 5/20
# 66/66 [==============================] - 1518s 23s/step - loss: 0.3612 - accuracy: 0.8454 - val_loss: 0.4502 - val_accuracy: 0.8271
# Epoch 6/20
# 66/66 [==============================] - 1545s 23s/step - loss: 0.3564 - accuracy: 0.8518 - val_loss: 0.4120 - val_accuracy: 0.8408
# Epoch 7/20
# 66/66 [==============================] - 1532s 23s/step - loss: 0.3417 - accuracy: 0.8526 - val_loss: 0.5084 - val_accuracy: 0.7578
# Epoch 8/20
# 66/66 [==============================] - 1535s 23s/step - loss: 0.3358 - accuracy: 0.8521 - val_loss: 0.4092 - val_accuracy: 0.8457
# Epoch 9/20
# 66/66 [==============================] - 1537s 23s/step - loss: 0.3376 - accuracy: 0.8540 - val_loss: 0.4629 - val_accuracy: 0.8262
# Epoch 10/20
# 66/66 [==============================] - 1536s 23s/step - loss: 0.3286 - accuracy: 0.8569 - val_loss: 0.4660 - val_accuracy: 0.8301
# Epoch 11/20
# 66/66 [==============================] - 1547s 23s/step - loss: 0.3329 - accuracy: 0.8564 - val_loss: 0.5428 - val_accuracy: 0.8369
# Epoch 12/20
# 66/66 [==============================] - 1561s 24s/step - loss: 0.3219 - accuracy: 0.8523 - val_loss: 0.3736 - val_accuracy: 0.8643
# Epoch 13/20
# 66/66 [==============================] - 1568s 24s/step - loss: 0.3395 - accuracy: 0.8545 - val_loss: 0.6334 - val_accuracy: 0.8076

# %%
import numpy as np
y_pred = model.predict_generator(val_data_generator, 1059 // 64+1)
Y_pred = np.argmax(y_pred, axis=1)
# Out:
# <ipython-input-28-f6fcdf5d96bf>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_pred = model.predict_generator(val_data_generator, 1059 // 64+1)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn import metrics

confusion_matrix = confusion_matrix(val_data_generator.classes, Y_pred)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
print(classification_report(val_data_generator.classes, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.64      0.76       241
#            1       0.99      0.86      0.92       229
#            2       0.85      0.88      0.87        92
#            3       0.97      0.66      0.78       218
#            4       0.62      1.00      0.76       279
#
#     accuracy                           0.81      1059
#    macro avg       0.87      0.81      0.82      1059
# weighted avg       0.86      0.81      0.81      1059

# %%
from sklearn.metrics import accuracy_score
accuracy_score(val_data_generator.classes, Y_pred)
# Out:
# 0.8073654390934845
