# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
import pandas as pd
import shutil

# %%
masks_path = "/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/data/sample_png_train_mask_data/"
imgs_path = "/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/data/sample_png_train_data/"
targets_path =  "/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/data/sample_png_train_img_mask_data/"
dcom_train_path = "/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/data/sample_train_data/"

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Pulmonary Fibrosis/notebooks/data_preprocess/f.csv")
df
# Out:
#                     Unnamed: 0    0
# 0    ID00007637202177411956430   30
# 1    ID00009637202177434476278  394
# 2    ID00010637202177584971671  106
# 3    ID00011637202177653955184   31
# 4    ID00012637202177665765362   49
# ..                         ...  ...
# 171  ID00419637202311204720264   28
# 172  ID00421637202311550012437   62
# 173  ID00422637202311677017371  473
# 174  ID00423637202312137826377  290
# 175  ID00426637202313170790466  408
#
# [176 rows x 2 columns]

# %%
df[df["Unnamed: 0"] == "ID00007637202177411956430"]["0"].values[0]
# Out:
# 30

# %%
c_img = 0
for id in os.listdir(masks_path):
  c_img += len(os.listdir(masks_path + id))
  # for slide in os.listdir(dcom_train_path + id):
    # c_img+= len(os.listdir(dcom_train_path + id ++ slide))
    # if slide[:2] == "ID":
      # if slide in os.listdir(dcom_train_path+ id) :
          # print(slide)
    #   # if id == slide:
    # if id in os.listdir(masks_path):
    #   # print(id, len(os.listdir(dcom_train_path + id)) , len(os.listdir(masks_path + id)))
    #   if len(os.listdir(imgs_path + id)) !=  len(os.listdir(masks_path + id)):
    #     print(id)
    # else: shutil.rmtree(imgs_path + id)

        # print(id ,len(os.listdir(dcom_train_path + id)))
        # if len(os.listdir(dcom_train_path + id)) == 0:
        #    print(id ,len(os.listdir(dcom_train_path + id)))

          # shutil.rmtree(masks_path + id)


        # if df[df["Unnamed: 0"] == id]["0"].values[0] != len(os.listdir(dcom_train_path + id)):
        #     print(id , df[df["Unnamed: 0"] == id]["0"] , "--->" , len(os.listdir(dcom_train_path + id)) )
      # if len(os.listdir(dcom_train_path + id + "/" + slide)) <= 20:
        #
        # shutil.rmtree(dcom_train_path + id + "/" + slide)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ec692dc8b679> in <cell line: 2>()
#       1 c_img = 0
#       2 for id in os.listdir(masks_path):
# ----> 3   c_img += len(os.listdir(masks_path + id))
#       4   # for slide in os.listdir(dcom_train_path + id):
#       5     # c_img+= len(os.listdir(dcom_train_path + id ++ slide))
#
# KeyboardInterrupt:

# %%
print(len(os.listdir(imgs_path)))
# Out:
# 167

# %%
print(len(os.listdir(masks_path)))
# Out:
# 167

# %%
c_img
# Out:
# 6287

# %%
print(len(os.listdir(targets_path)))
# Out:
# 167
